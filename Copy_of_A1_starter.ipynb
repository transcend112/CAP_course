# %% [markdown]
# <a href="https://colab.research.google.com/github/transcend112/CAP_coursex/blob/master/Copy_of_A1_starter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # COP 5768 - Intro to Data Science
#
# ## Assignment 1: A crash course in Python
#
# This is the starter ("skeleton") Jupyter notebook for the first assignment.
#
# It is based on a selected subset of tutorials from https://www.learnpython.org/
#
# Please see detailed instructions / guidelines on Canvas.
#
# ---
#
#
# Name: [add your name here]
#
# Open and Execute in Google Colaboratory:https://colab.research.google.com/drive/1mJmONwhrZcSM5ADLzk9sI4hbIGRg2pgA?usp=sharing

# %% [markdown]
# ## Example of a section
#
# The cell below shows an example of a section.
#
# Notice how it's been ***edited to reflect what you have learned*** (rather than just copying and pasting the original contents).

# %% [markdown]
# ### Hello, World!
#
# The first thing I learned, not surprisingly, was how to print a "Hello, World!" message on the screen.
#
# The code below is compatible with the syntax for the `print` statement in Python 3.

# %%
# Hello, World!
print("Hello, World!") # print welcome message
# Out:
# Hello, World!

# %% [markdown]
# ![HelloWorld.png](data:image/png;base64,...)

# %% [markdown]
# ## Take it from here
#
# Add all meaningful sections, code snippets, plots, screenshots, etc. for the selected tutorials (se guidelines for details).

# %% [markdown]
# ###Concluding Remarks
#
# I also did this...
